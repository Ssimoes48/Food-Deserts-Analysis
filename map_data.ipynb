# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os



# Import API key
from api_keys import g_key

# %% [markdown]
# merge CSV files into a combined dataframe for analysis

# %%
file = "output/my_combined.csv"

county_df = pd.read_csv(file)
county_df.head()

file2 = "Resources/countycoordinates.xlsx"

coord_df = pd.read_excel(file2)
clean_coord = coord_df[["State", "County", "Latitude", "Longitude"]]
clean_coord

data_loc = pd.DataFrame.merge(county_df, clean_coord, on=["State", "County"])



#data_loc.to_csv('output/clean_with_lat_long.csv', index = False)

data_loc.head()
# Out:
#      State   County  POP2010  OHU2010  PovertyRate  MedianFamilyIncome  \
# 0  Alabama  Autauga    54571    20221    13.858333        61082.916667
# 1  Alabama  Baldwin   182265    73180    14.358065        60664.935484
# 2  Alabama  Barbour    27457     9820    24.533333        43123.000000
# 3  Alabama     Bibb    22915     7953    16.025000        43362.500000
# 4  Alabama   Blount    57322    21578    17.911111        52136.000000
#
#    LILATracts_1And10  LILATracts_halfAnd10  LILATracts_1And20  \
# 0                  2                     2                  1
# 1                  3                     3                  3
# 2                  3                     3                  1
# 3                  0                     0                  0
# 4                  0                     0                  0
#
#    LILATracts_Vehicle  ...  # Deaths  Years of Potential Life Lost Rate  \
# 0                   2  ...     830.0                             9158.0
# 1                   2  ...    2573.0                             7394.0
# 2                   2  ...     413.0                             8573.0
# 3                   1  ...     407.0                            11766.0
# 4                   2  ...     906.0                             9333.0
#
#    % Obese  % Fair/Poor  # Diabetics  # Violent Crimes  # Unemployed  \
# 0       34           18        711.0             145.0        1327.0
# 1       27           16       2615.0             415.0        4791.0
# 2       44           25        525.0              85.0         771.0
# 3       40           20        333.0              33.0         561.0
# 4       35           19        705.0             123.0        1316.0
#
#    % Children in Poverty   Latitude  Longitude
# 0                   19.0  32.534920 -86.642749
# 1                   20.0  30.660970 -87.749840
# 2                   45.0  31.869603 -85.393197
# 3                   29.0  32.998644 -87.126439
# 4                   22.0  33.980867 -86.567371
#
# [5 rows x 39 columns]

# %%
#add additional data column to dataframe and merge again with medicare data

file = "output/clean_with_lat_long.csv"

longlat_df = pd.read_csv(file)
longlat_df.head()

file2 = "Resources/Medicare_Enrollment_2017.csv"

health_df = pd.read_csv(file2)

clean_data2 = pd.DataFrame.merge(longlat_df, health_df, on=["State", "County"])



#clean_data2.to_csv('output/clean_data2.csv', index = False)

clean_data2.head()
# Out:
#      State   County  POP2010  OHU2010  PovertyRate  MedianFamilyIncome  \
# 0  Alabama  Autauga    54571    20221    13.858333        61082.916667
# 1  Alabama  Baldwin   182265    73180    14.358065        60664.935484
# 2  Alabama  Barbour    27457     9820    24.533333        43123.000000
# 3  Alabama     Bibb    22915     7953    16.025000        43362.500000
# 4  Alabama   Blount    57322    21578    17.911111        52136.000000
#
#    LILATracts_1And10  LILATracts_halfAnd10  LILATracts_1And20  \
# 0                  2                     2                  1
# 1                  3                     3                  3
# 2                  3                     3                  1
# 3                  0                     0                  0
# 4                  0                     0                  0
#
#    LILATracts_Vehicle  ...  Years of Potential Life Lost Rate  % Obese  \
# 0                   2  ...                             9158.0       34
# 1                   2  ...                             7394.0       27
# 2                   2  ...                             8573.0       44
# 3                   1  ...                            11766.0       40
# 4                   2  ...                             9333.0       35
#
#    % Fair/Poor  # Diabetics  # Violent Crimes  # Unemployed  \
# 0           18        711.0             145.0        1327.0
# 1           16       2615.0             415.0        4791.0
# 2           25        525.0              85.0         771.0
# 3           20        333.0              33.0         561.0
# 4           19        705.0             123.0        1316.0
#
#    % Children in Poverty   Latitude  Longitude  Original Medicare
# 0                   19.0  32.534920 -86.642749               5784
# 1                   20.0  30.660970 -87.749840              28388
# 2                   45.0  31.869603 -85.393197               4372
# 3                   29.0  32.998644 -87.126439               2480
# 4                   22.0  33.980867 -86.567371               6070
#
# [5 rows x 40 columns]

# %%
# Out:
#         State      County  POP2010  OHU2010  PovertyRate  MedianFamilyIncome  \
# 0     Alabama     Autauga    54571    20221    13.858333        61082.916667
# 1     Alabama     Baldwin   182265    73180    14.358065        60664.935484
# 2     Alabama     Barbour    27457     9820    24.533333        43123.000000
# 3     Alabama        Bibb    22915     7953    16.025000        43362.500000
# 4     Alabama      Blount    57322    21578    17.911111        52136.000000
# ...       ...         ...      ...      ...          ...                 ...
# 3088  Wyoming  Sweetwater    43806    16475    11.841667        81835.083333
# 3089  Wyoming       Teton    21294     8973     8.100000        89555.250000
# 3090  Wyoming       Uinta    21118     7668    14.166667        65312.666667
# 3091  Wyoming    Washakie     8533     3492    14.133333        62213.666667
# 3092  Wyoming      Weston     7208     3021    12.100000        75233.000000
#
#       LILATracts_1And10  LILATracts_halfAnd10  LILATracts_1And20  \
# 0                     2                     2                  1
# 1                     3                     3                  3
# 2                     3                     3                  1
# 3                     0                     0                  0
# 4                     0                     0                  0
# ...                 ...                   ...                ...
# 3088                  0                     0                  0
# 3089                  0                     0                  0
# 3090                  0                     0                  0
# 3091                  0                     1                  0
# 3092                  0                     0                  0
#
#       LILATracts_Vehicle  ...  % Fair/Poor  # Diabetics  # Violent Crimes  \
# 0                      2  ...           18        711.0             145.0
# 1                      2  ...           16       2615.0             415.0
# 2                      2  ...           25        525.0              85.0
# 3                      1  ...           20        333.0              33.0
# 4                      2  ...           19        705.0             123.0
# ...                  ...  ...          ...          ...               ...
# 3088                   2  ...           16        469.0             159.0
# 3089                   0  ...           12        104.0               NaN
# 3090                   0  ...           15        243.0               8.0
# 3091                   0  ...           14        156.0               7.0
# 3092                   0  ...           14        103.0               9.0
#
#       # Unemployed  % Children in Poverty   Latitude   Longitude  \
# 0           1327.0                   19.0  32.534920  -86.642749
# 1           4791.0                   20.0  30.660970  -87.749840
# 2            771.0                   45.0  31.869603  -85.393197
# 3            561.0                   29.0  32.998644  -87.126439
# 4           1316.0                   22.0  33.980867  -86.567371
# ...            ...                    ...        ...         ...
# 3088        1053.0                   10.0  41.659496 -108.879431
# 3089         558.0                    8.0  43.934637 -110.589810
# 3090         475.0                   12.0  41.287492 -110.547562
# 3091         174.0                   16.0  43.904997 -107.682861
# 3092         133.0                   13.0  43.840485 -104.567830
#
#       Original Medicare  Environment Category  Inverse Index
# 0                  5784               Healthy            3.1
# 1                 28388               Healthy            2.5
# 2                  4372          Food Deserts            5.1
# 3                  2480               Healthy            2.7
# 4                  6070               Healthy            1.7
# ...                 ...                   ...            ...
# 3088               5641               Healthy            1.9
# 3089               3122               Healthy            2.0
# 3090               2804               Healthy            2.5
# 3091               1812               Healthy            2.0
# 3092               1447               Healthy            2.0
#
# [3093 rows x 42 columns]

# %%
#print column to see data

clean_data2["Food Environment Index"]
# Out:
# 0       6.9
# 1       7.5
# 2       4.9
# 3       7.3
# 4       8.3
#        ...
# 3088    8.1
# 3089    8.0
# 3090    7.5
# 3091    8.0
# 3092    8.0
# Name: Food Environment Index, Length: 3093, dtype: float64

# %%
bottomten = data_loc["Food Environment Index"].quantile(q=0.10)
bottomten
# Out:
# 5.5

# %%
bins = [0, 5.5, 10]
ranges = ["Food Deserts", "Healthy"]

# %%
binned_if_desert = pd.cut(data_loc["Food Environment Index"], bins, labels=ranges)

# %%
data_loc["Environment Category"] = binned_if_desert
data_loc.reset_index(drop=True,inplace=True)

data_loc.head()

healthy_df = data_loc.loc[data_loc["Environment Category"] == "Healthy"]
healthy_df

healthy_df.to_csv('output/healthy_df.csv', index = False)

desert_df = data_loc.loc[data_loc["Environment Category"] == "Food Deserts"]
desert_df
healthy_df.to_csv('output/healthy_df.csv', index = False)
# Out:
#               State     County  POP2010  OHU2010  PovertyRate  \
# 2           Alabama    Barbour    27457     9820    24.533333
# 5           Alabama    Bullock    10914     3745    19.333333
# 11          Alabama    Choctaw    13859     5866    23.000000
# 12          Alabama     Clarke    25833    10337    26.955556
# 17          Alabama    Conecuh    13228     5625    29.400000
# ...             ...        ...      ...      ...          ...
# 2915     Washington      Ferry     7551     3190    24.233333
# 2917     Washington   Garfield     2266      989    12.400000
# 2940     Washington  Wahkiakum     3978     1737    21.900000
# 2996  West Virginia     Wetzel    16583     6968    18.920000
# 3039      Wisconsin  Menominee     4232     1318    33.050000
#
#       MedianFamilyIncome  LILATracts_1And10  LILATracts_halfAnd10  \
# 2           43123.000000                  3                     3
# 5           45273.666667                  2                     2
# 11          48360.250000                  1                     1
# 12          44922.666667                  3                     3
# 17          34702.800000                  4                     4
# ...                  ...                ...                   ...
# 2915        44849.666667                  2                     2
# 2917        58750.000000                  0                     0
# 2940        49523.000000                  1                     1
# 2996        50719.800000                  3                     3
# 3039        39193.000000                  1                     1
#
#       LILATracts_1And20  LILATracts_Vehicle  ...  \
# 2                     1                   2  ...
# 5                     0                   2  ...
# 11                    0                   2  ...
# 12                    1                   4  ...
# 17                    0                   3  ...
# ...                 ...                 ...  ...
# 2915                  1                   1  ...
# 2917                  0                   0  ...
# 2940                  0                   0  ...
# 2996                  1                   2  ...
# 3039                  0                   0  ...
#
#       Years of Potential Life Lost Rate  % Obese  % Fair/Poor  # Diabetics  \
# 2                                8573.0       44           25        525.0
# 5                               10858.0       43           28        212.0
# 11                              12937.0       41           25        425.0
# 12                               9469.0       38           23        508.0
# 17                              12828.0       36           28        346.0
# ...                                 ...      ...          ...          ...
# 2915                            10071.0       28           19        141.0
# 2917                                NaN       33           14         49.0
# 2940                            10997.0       31           14         96.0
# 2996                             9151.0       33           24        277.0
# 3039                            14635.0       43           33         68.0
#
#       # Violent Crimes  # Unemployed  % Children in Poverty   Latitude  \
# 2                 85.0         771.0                   45.0  31.869603
# 5                 32.0         371.0                   51.0  32.100554
# 11                14.0         399.0                   34.0  32.019611
# 12               110.0         940.0                   31.0  31.676660
# 17                72.0         429.0                   41.0  31.429272
# ...                ...           ...                    ...        ...
# 2915              12.0         251.0                   31.0  48.470145
# 2917               4.0          57.0                   22.0  46.431559
# 2940               2.0         115.0                   25.0  46.291134
# 2996              13.0         721.0                   29.0  39.605263
# 3039               2.0         157.0                   51.0  45.004367
#
#        Longitude  Environment Category
# 2     -85.393197          Food Deserts
# 5     -85.715697          Food Deserts
# 11    -88.263201          Food Deserts
# 12    -87.830810          Food Deserts
# 17    -86.993674          Food Deserts
# ...          ...                   ...
# 2915 -118.516586          Food Deserts
# 2917 -117.545169          Food Deserts
# 2940 -123.433470          Food Deserts
# 2996  -80.639098          Food Deserts
# 3039  -88.710006          Food Deserts
#
# [331 rows x 40 columns]

# %%
desert_df["Food Environment Index"].count()
# Out:
# 331

# %%
healthy_df["Food Environment Index"].count()
# Out:
# 2763

# %%
clean_data2 

#create inverse values so that the heat layer map shows green for access to food and red for no access.  

clean_data2["Inverse Index"] = clean_data2["Food Environment Index"].apply(lambda x: abs(x - 10))

clean_data2["Inverse Index"]
# Out:
# 0       3.1
# 1       2.5
# 2       5.1
# 3       2.7
# 4       1.7
#        ...
# 3088    1.9
# 3089    2.0
# 3090    2.5
# 3091    2.0
# 3092    2.0
# Name: Inverse Index, Length: 3093, dtype: float64

# %%
#print column headers to easy viewing when analyzing data
for col in clean_data2.columns:
    print(col)
# Out:
# State
# County
# POP2010
# OHU2010
# PovertyRate
# MedianFamilyIncome
# LILATracts_1And10
# LILATracts_halfAnd10
# LILATracts_1And20
# LILATracts_Vehicle
# LAPOP1_10
# LAPOP05_10
# LAPOP1_20
# LALOWI1_10
# LALOWI05_10
# LALOWI1_20
# lapophalf
# TractKids
# TractSeniors
# TractWhite
# TractBlack
# TractAsian
# TractNHOPI
# TractAIAN
# TractOMultir
# TractHispanic
# TractHUNV
# TractSNAP
# Food Environment Index
# # Deaths
# Years of Potential Life Lost Rate
# % Obese
# % Fair/Poor
# # Diabetics
# # Violent Crimes
# # Unemployed
# % Children in Poverty
# Latitude
# Longitude
# Original Medicare
# Inverse Index

# %% [markdown]
# Create heat map of US with data by county showing the Food Environment Index Inverse 0 is best, 10 is worst

# %%
locations = clean_data2[["Latitude", "Longitude"]]

food_env = clean_data2["Inverse Index"]

# %%
# Plot Heatmap
fig = gmaps.figure()


# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=food_env, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=.25)


# Add layer
fig.add_layer(heat_layer)

#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = desert_df[["Latitude", "Longitude"]]

food_envd = desert_df["Food Environment Index"]

# %%
# Plot Heatmap
fig = gmaps.figure()


# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=food_envd, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=.25)


# Add layer
fig.add_layer(heat_layer)

#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Obesity
#
# create a heat map to show obesity % for US by county. 100% is red, 0% is faint green

# %%
locations = data_loc[["Latitude", "Longitude"]]

obese = data_loc["% Obese"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()


# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=obese, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=.25)


# Add layer
fig.add_layer(heat_layer)

#Display figure
fig

# %% [markdown]
# create heat maps by State Montana. create dataframe of Just Montana

# %%
montana = clean_data2.loc[data_loc["State"] == "Montana",:]


montana_healthy = healthy_df.loc[data_loc["State"] == "Montana",:]

#montana_healthy.head()

montana_desert = desert_df.loc[data_loc["State"] == "Montana",:]
montana_desert.head()
# Out:
#         State    County  POP2010  OHU2010  PovertyRate  MedianFamilyIncome  \
# 1588  Montana  Big Horn    12865     4004        31.22             46813.2
# 1589  Montana    Blaine     6491     2357        29.80             38925.5
# 1592  Montana    Carter     1160      532        10.90             61429.0
# 1594  Montana  Chouteau     5813     2294        18.50             54260.0
# 1596  Montana   Daniels     1751      798         6.70             63603.0
#
#       LILATracts_1And10  LILATracts_halfAnd10  LILATracts_1And20  \
# 1588                  4                     4                  1
# 1589                  1                     1                  1
# 1592                  0                     0                  0
# 1594                  1                     1                  1
# 1596                  0                     0                  0
#
#       LILATracts_Vehicle  ...  Years of Potential Life Lost Rate  % Obese  \
# 1588                   1  ...                            15117.0       39
# 1589                   1  ...                            11508.0       36
# 1592                   0  ...                                NaN       25
# 1594                   1  ...                            10190.0       26
# 1596                   0  ...                                NaN       26
#
#       % Fair/Poor  # Diabetics  # Violent Crimes  # Unemployed  \
# 1588           22        193.0              28.0         372.0
# 1589           20        100.0              10.0         120.0
# 1592           11         13.0               0.0          23.0
# 1594           17         74.0               6.0          75.0
# 1596           10         27.0               2.0          25.0
#
#       % Children in Poverty   Latitude   Longitude  Environment Category
# 1588                   40.0  45.423382 -107.489853          Food Deserts
# 1589                   40.0  48.432676 -108.958602          Food Deserts
# 1592                   23.0  45.516757 -104.536159          Food Deserts
# 1594                   23.0  47.880584 -110.435224          Food Deserts
# 1596                   10.0  48.783797 -105.548617          Food Deserts
#
# [5 rows x 40 columns]

# %%
montana_healthy["Environment Category"].count()
# Out:
# 41

# %%
montana_desert["Environment Category"].count()
# Out:
# 15

# %%
#heat map of inverse data of Food Environment for Montana

locations2 = montana[["Latitude", "Longitude"]]


food_env2 = montana["Inverse Index"]

# %%
# Plot Heatmap
fig = gmaps.figure()


# Create heat layer
heat_layer = gmaps.heatmap_layer(locations2, weights=food_env2, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=.25)


# Add layer
fig.add_layer(heat_layer)

#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# #heat map of inverse data of Food Environment for Montana Desert

# locations2 = montana_desert[["Latitude", "Longitude"]]


# food_env3 = montana_desert["Inverse Index"]

# %%
# # Plot Heatmap
# fig = gmaps.figure()


# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locations2, weights=food_env3, 
#                                  dissipating=False, max_intensity=10,
#                                  point_radius=.25)


# # Add layer
# fig.add_layer(heat_layer)

# #Display figure
# fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create heat map for Obese % for Montana Healthy

locations = montana_healthy[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
obese2 = montana_healthy["% Obese"]

# %%
# Using the template add the Obese % marks to the heatmap
info_box_template = """
<dl>
<dt>County: </dt><dd>{County}</dd>
<dt>Obesity %: </dt><dd>{% Obese}</dd>
</dl>
"""
# Store the DataFrame Row

# NOTE: be sure to update with your DataFrame name
obese_info = [info_box_template.format(**row) for index, row in montana_healthy.iterrows()]
locations = montana_healthy[["Latitude", "Longitude"]]

# %%
# Plot Heatmap obesity of montana non food deserts
fig = gmaps.figure()
marker_locations = montana_healthy[["Latitude", "Longitude"]]
marker_layer2 = gmaps.marker_layer(locations, info_box_content=obese_info)

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=obese2, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=.25)


# Add layer

fig.add_layer(heat_layer)
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig.add_layer(marker_layer2)
#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# # Plot Heatmap
# fig = gmaps.figure()
# marker_locations = montana_healthy[["Latitude", "Longitude"]]

# # Create heat layer
# heat_layer2 = gmaps.heatmap_layer(locations2, weights=obese2, 
#                                  dissipating=False, max_intensity=100,
#                                  point_radius=.25)


# # Add layer
# marker_layer2 = gmaps.marker_layer(locations, info_box_content=obese_info)

# fig.add_layer(heat_layer2)
# fig.add_layer(markers)
# fig.add_layer(marker_layer2)
# #Display figure
# fig

# %%
#create heat map for Obese % for Montana desert

locations = montana_desert[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
obese2 = montana_desert["% Obese"]

# %%
# Using the template add the Obese % marks to the heatmap
info_box_template = """
<dl>
<dt>County: </dt><dd>{County}</dd>
<dt>Obesity %: </dt><dd>{% Obese}</dd>
</dl>
"""
# Store the DataFrame Row

# NOTE: be sure to update with your DataFrame name
obese_info = [info_box_template.format(**row) for index, row in montana_desert.iterrows()]
locations = montana_desert[["Latitude", "Longitude"]]

# %%
# Plot Heatmap of obestiy in montana food deserts
fig = gmaps.figure()
marker_locations = montana_desert[["Latitude", "Longitude"]]
marker_layer2 = gmaps.marker_layer(locations, info_box_content=obese_info)

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=obese2, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=.25)


# Add layer

fig.add_layer(heat_layer)
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig.add_layer(marker_layer2)
#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
gmaps.configure(api_key= g_key)

marker_locations = montana[["Latitude", "Longitude"]]
    

fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Using the template add the food environment marks to the heatmap
info_box_template = """
<dl>
<dt>County: </dt><dd>{County}</dd>
<dt>Food Environment Index: </dt><dd>{Food Environment Index}</dd>
</dl>
"""
# Store the DataFrame Row

# NOTE: be sure to update with your DataFrame name
county_info = [info_box_template.format(**row) for index, row in montana.iterrows()]
locations = montana[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=county_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)

heat_layer = gmaps.heatmap_layer(locations2, weights=food_env2, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=.25)

fig.add_layer(heat_layer)
fig

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
gmaps.configure(api_key= g_key)

marker_locations = montana[["Latitude", "Longitude"]]
    

fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)

fig

# %%
# Using the template add the food environment Index marks to the heatmap
info_box_template = """
<dl>
<dt>County: </dt><dd>{County}</dd>
<dt>Food Environment Index: </dt><dd>{Food Environment Index}</dd>
</dl>
"""


# NOTE: be sure to update with your DataFrame name
county_info = [info_box_template.format(**row) for index, row in montana.iterrows()]
locations = montana[["Latitude", "Longitude"]]

# %% [markdown]
# # Diabetics

# %%
locations = data_loc[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
diabetic = data_loc["# Diabetics"].astype(float)

# %%
# Plot Heatmap US diabetic
fig = gmaps.figure()


# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=diabetic, 
                                 dissipating=False, max_intensity=3000,
                                 point_radius=.25)


# Add layer
fig.add_layer(heat_layer)

#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#montana healthy
locations1 = montana_healthy[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
diabetic2 = montana_healthy["# Diabetics"]

# %%
# Using the template add the diabetic # marks to the heatmap
info_box_template = """
<dl>
<dt>County: </dt><dd>{County}</dd>
<dt># of Diabetics: </dt><dd>{# Diabetics}</dd>
</dl>
"""


# NOTE: be sure to update with your DataFrame name
diabetic_info = [info_box_template.format(**row) for index, row in montana_healthy.iterrows()]
locations = montana_healthy[["Latitude", "Longitude"]]

# %%
fig = gmaps.figure()


# Create heat layer on diebetic
heat_layer = gmaps.heatmap_layer(locations1, weights=diabetic2, 
                                 dissipating=False, max_intensity=800,
                                 point_radius=.25)


# Add layer
fig.add_layer(heat_layer)
fig.add_layer(markers)
marker_layer = gmaps.marker_layer(locations, info_box_content=diabetic_info)

fig.add_layer(marker_layer)
#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#montana desert
locations2 = montana_desert[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
diabetic3 = montana_desert["# Diabetics"]

# %%
# Using the template add the diabetic # marks to the heatmap
info_box_template = """
<dl>
<dt>County: </dt><dd>{County}</dd>
<dt># of Diabetics: </dt><dd>{# Diabetics}</dd>
</dl>
"""


# NOTE: be sure to update with your DataFrame name
diabetic_info = [info_box_template.format(**row) for index, row in montana_desert.iterrows()]
locations = montana_desert[["Latitude", "Longitude"]]

# %%
fig = gmaps.figure()


# Create heat layer for montana food deserts for # of diabetic
heat_layer = gmaps.heatmap_layer(locations2, weights=diabetic3, 
                                 dissipating=False, max_intensity=800,
                                 point_radius=.25)


# Add layer
fig.add_layer(heat_layer)
fig.add_layer(markers)
marker_layer = gmaps.marker_layer(locations, info_box_content=diabetic_info)

fig.add_layer(marker_layer)
#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Unemployed

# %%
locations = data_loc[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
unemployed = data_loc["# Unemployed"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()


# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=unemployed, 
                                 dissipating=False, max_intensity=3000,
                                 point_radius=.25)


# Add layer
fig.add_layer(heat_layer)

#Display figure
fig

# %%
locations = montana[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
unemployed2 = montana["# Unemployed"]

# %%
# Using the template add the # unemployed marks to the heatmap
info_box_template = """
<dl>
<dt>County: </dt><dd>{County}</dd>
<dt># of Unemployed: </dt><dd>{# Unemployed}</dd>
</dl>
"""

# NOTE: be sure to update with your DataFrame name
employmemt_info = [info_box_template.format(**row) for index, row in montana.iterrows()]
locations = montana[["Latitude", "Longitude"]]

# %%
fig = gmaps.figure()


# Create heat layer
heat_layer = gmaps.heatmap_layer(locations2, weights=unemployed2, 
                                 dissipating=False, max_intensity=800,
                                 point_radius=.25)


# Add layer
fig.add_layer(heat_layer)
fig.add_layer(markers)
marker_layer = gmaps.marker_layer(locations, info_box_content=employmemt_info)
fig.add_layer(marker_layer)
#Display figure
fig

# %%
#print data frame for review

montana_healthy[["County", "POP2010", "% Obese", "# Diabetics", "Food Environment Index"]]



#montana_healthy["Percent D"] = montana_healthy["# Diabetics"] / montana_healthy["POP2010"] * 100
# Out:
#                County  POP2010  % Obese  # Diabetics  Food Environment Index
# 1587       Beaverhead     9246       24        126.0                     7.3
# 1590       Broadwater     5612       30         64.0                     7.3
# 1591           Carbon    10078       24        131.0                     7.5
# 1593          Cascade    81327       28        995.0                     7.3
# 1595           Custer    11699       31        168.0                     6.6
# 1597           Dawson     8966       31        126.0                     7.4
# 1598       Deer Lodge     9298       26        183.0                     7.8
# 1599           Fallon     2890       28         35.0                     8.3
# 1600           Fergus    11586       26        146.0                     7.2
# 1601         Flathead    90928       23        838.0                     7.7
# 1602         Gallatin    89513       16        528.0                     7.8
# 1603         Garfield     1206       26         17.0                     6.8
# 1606          Granite     3079       29         45.0                     5.9
# 1607             Hill    16096       33        227.0                     6.2
# 1608        Jefferson    11406       28        137.0                     7.5
# 1609     Judith Basin     2072       29         28.0                     6.3
# 1610             Lake    28746       28        511.0                     7.0
# 1611  Lewis and Clark    63395       24        648.0                     7.9
# 1612          Liberty     2339       27         24.0                     6.1
# 1613          Lincoln    19687       29        309.0                     6.9
# 1614          Madison     7691       22        109.0                     7.3
# 1615           McCone     1734       24         33.0                     5.7
# 1617          Mineral     4223       28         67.0                     5.7
# 1618         Missoula   109299       22       1029.0                     7.1
# 1619      Musselshell     4538       28         78.0                     6.8
# 1620             Park    15636       23        174.0                     6.7
# 1622         Phillips     4253       29         62.0                     7.1
# 1624     Powder River     1743       27         15.0                     6.4
# 1625           Powell     7027       28         90.0                     7.3
# 1627          Ravalli    40212       23        562.0                     7.7
# 1628         Richland     9746       31        168.0                     7.6
# 1630          Rosebud     9233       36        124.0                     6.9
# 1632         Sheridan     3384       30         57.0                     7.5
# 1633       Silver Bow    34200       26        440.0                     6.9
# 1634       Stillwater     9117       22        134.0                     8.3
# 1635      Sweet Grass     3651       24         57.0                     7.6
# 1636            Teton     6073       27         59.0                     6.4
# 1637            Toole     5324       27         50.0                     7.0
# 1639           Valley     7369       29        109.0                     7.0
# 1641           Wibaux     1017       27         21.0                     6.8
# 1642      Yellowstone   147972       25       1679.0                     7.8

# %%
#print dataframe for review
montana_desert[["County", "POP2010", "% Obese", "# Diabetics", "Food Environment Index"]]
# Out:
#              County  POP2010  % Obese  # Diabetics  Food Environment Index
# 1588       Big Horn    12865       39        193.0                     4.5
# 1589         Blaine     6491       36        100.0                     5.3
# 1592         Carter     1160       25         13.0                     4.4
# 1594       Chouteau     5813       26         74.0                     4.3
# 1596        Daniels     1751       26         27.0                     5.2
# 1604        Glacier    13399       34        183.0                     5.5
# 1605  Golden Valley      884       24          NaN                     3.9
# 1616        Meagher     1891       24         26.0                     3.1
# 1621      Petroleum      494       25          NaN                     3.4
# 1623        Pondera     6153       29         81.0                     5.4
# 1626        Prairie     1179       26         24.0                     4.4
# 1629      Roosevelt    10425       37        167.0                     4.7
# 1631        Sanders    11413       27        224.0                     5.1
# 1638       Treasure      718       26         16.0                     4.0
# 1640      Wheatland     2168       25         23.0                     3.4
